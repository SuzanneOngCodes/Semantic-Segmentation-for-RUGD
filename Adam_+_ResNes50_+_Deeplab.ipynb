# %% [markdown]
# <a href="https://colab.research.google.com/github/SuzanneOngCodes/Semantic-segmentation/blob/main/Adam_%2B_ResNes50_%2B_Deeplab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ResNet50 + Deeplab backbone with the focus to test on performance betweeen different architectures**

# %%
# Comment out %%capture to view downloading progress
# %%capture

## If there is a problem in running the dataloader, try:
# !pip uninstall albumentations
## Restart runtime and continue
# !pip install --upgrade albumentations

# Set flag to train the model or not. If set to 'False', only prediction is performed (using an older model checkpoint)
# !pip uninstall segmentation_models.pytorch
# !pip install segmentation-models-pytorch==0.2.0

# %%
## Initial setup - removing redundant directory
## Average time to compute - approx. 1-2 mins
# Comment out %%capture to view downloading progress
# %%capture
# !rm -rf sample_data/

# !pip install opencv-python-headless==4.5.2.52
# !pip install git+https://github.com/pytorch/pytorch.git
# !pip install torchmetrics

# %%
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.9.0-py3-none-any.whl (418 kB)
#      |████████████████████████████████| 418 kB 8.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.2.0)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.9.0

# %%
# Comment out %%capture to view downloading progress
# %%capture
from torch.utils.data import Dataset, DataLoader
import torch
from torchvision import transforms
import shutil
from torch import nn
from tqdm.notebook import tqdm
import os
from PIL import Image
import pandas as pd
import cv2 as cv
import numpy as np
import albumentations as album
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import torchvision
from torch.utils.data import DataLoader

# %% [markdown]
# # Import dataset here.
# **In this project, we will be starting off with RUGD offroad dataset from** http://rugd.vision

# %%
# Comment out %%capture to view downloading progress
# %%capture

if os.path.exists("/content/data") == False : 
  # !mkdir data
  # %cd data

  # Download and unzip raw frames from videos
  # !wget http://rugd.vision/data/RUGD_frames-with-annotations.zip
  # !unzip RUGD_frames-with-annotations.zip

  # Download and unzip raw annotations
  # !wget http://rugd.vision/data/RUGD_annotations.zip
  # !unzip RUGD_annotations.zip

  # Remove zip files
  # !rm -r RUGD_annotations.zip
  # !rm -r RUGD_frames-with-annotations.zip

  # %mkdir "RUGD_frames-with-annotations"/training 
  # %mkdir "RUGD_frames-with-annotations"/validation
  # %mkdir "RUGD_frames-with-annotations"/testing
  # %mkdir RUGD_annotations/training 
  # %mkdir RUGD_annotations/validation
  # %mkdir RUGD_annotations/testing

# %% [markdown]
# # Define labels based on classes

# %%
id2label = {
    0: 'dirt',
    1: 'sand',
    2: 'grass',
    3: 'tree',
    4: 'pole',
    5: 'water',
    6: 'sky',
    7: 'vehicle',
    8: 'container/generic-object',
    9: 'asphalt',
    10: 'gravel',
    11: 'building',
    12: 'mulch',
    13: 'rock-bed',
    14: 'log',
    15: 'bicycle',
    16: 'person',
    17: 'fence',
    18: 'bush',
    19: 'sign',
    20: 'rock',
    21: 'bridge',
    22: 'concrete', 
    23: 'picnic-table'
 }

id2label = {int(k): v for k, v in id2label.items()}
label2id = {v: k for k, v in id2label.items()}

## Check if there are 24 labels
num_labels = len(id2label)
print(num_labels)
CLASSES = ["dirt", "sand", "grass", "tree", "pole", "water", "sky", 
        "vehicle", "container/generic-object", "asphalt", "gravel", 
        "building", "mulch", "rock-bed", "log", "bicycle", "person", 
        "fence", "bush", "sign", "rock", "bridge", "concrete", "picnic-table"]

COLORMAP = [[ 108, 64, 20 ], [ 255, 229, 204 ],[ 0, 102, 0 ],[ 0, 255, 0 ],
            [ 0, 153, 153 ],[ 0, 128, 255 ],[ 0, 0, 255 ],[ 255, 255, 0 ],[ 255, 0, 127 ],
            [ 64, 64, 64 ],[ 255, 128, 0 ],[ 255, 0, 0 ],[ 153, 76, 0 ],[ 102, 102, 0 ],
            [ 102, 0, 0 ],[ 0, 255, 128 ],[ 204, 153, 255 ],[ 102, 0, 204 ],[ 255, 153, 204 ],
            [ 0, 102, 102 ],[ 153, 204, 255 ],[ 102, 255, 255 ],[ 101, 101, 11 ],[ 114, 85, 47 ] ]

color_id = {tuple(c):i for i, c in enumerate(COLORMAP)}

select_class_indices = [CLASSES.index(cls.lower()) for cls in CLASSES]
select_class_rgb_values =  np.array(COLORMAP)[select_class_indices]
# Out:
# 24

# %% [markdown]
# # **Data Preprocessing**

# %%
# Resize width and height
def get_augmentation():
    train_transform = [
        album.Resize(304, 304),
        album.PadIfNeeded(min_height=100, min_width=100, always_apply=True, border_mode=0),
        album.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        album.OneOf(
            [
                album.HorizontalFlip(p=1),
                album.VerticalFlip(p=1),
                album.RandomRotate90(p=1),
            ],
            p=0.5,
        ),
    ]
    return album.Compose(train_transform)

def get_validation_augmentation():
    train_transform = [
        album.Resize(304, 304),
        album.PadIfNeeded(min_height=100, min_width=100, always_apply=True, border_mode=0),
    ]
    return album.Compose(train_transform)

def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')

def get_preprocessing(preprocessing_fn=None):
    _transform = []
    if preprocessing_fn:
        _transform.append(album.Lambda(image=preprocessing_fn))
    _transform.append(album.Lambda(image=to_tensor, mask=to_tensor))
        
    return album.Compose(_transform)

# %%
# Helper function to visualize on a sample image 
def visualize(**images):
    """
    Plot images in one row
    """
    n_images = len(images)
    plt.figure(figsize=(20,8))
    for idx, (name, image) in enumerate(images.items()):
        plt.subplot(1, n_images, idx + 1)
        plt.xticks([]); 
        plt.yticks([])
        # get title from the parameter names
        plt.title(name.replace('_',' ').title(), fontsize=20)
        plt.imshow(image)
    plt.show()

# Perform one hot encoding on label
def one_hot_encode(label, label_values):
    """
    Convert a segmentation image label array to one-hot format
    by replacing each pixel value with a vector of length num_classes
    # Arguments
        label: The 2D array segmentation image label
        label_values
        
    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of num_classes
    """
    semantic_map = []
    for colour in label_values:
        equality = np.equal(label, colour)
        class_map = np.all(equality, axis = -1)
        semantic_map.append(class_map)
    semantic_map = np.stack(semantic_map, axis=-1)

    return semantic_map
    
# Perform reverse one-hot-encoding on labels / preds
def reverse_one_hot(image):
    """
    Transform a 2D array in one-hot format (depth is num_classes),
    to a 2D array with only 1 channel, where each pixel value is
    the classified class key.
    # Arguments
        image: The one-hot format image 
        
    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of 1, where each pixel value is the classified 
        class key.
    """
    x = np.argmax(image, axis = -1)
    return x

# Perform colour coding on the reverse-one-hot outputs
def colour_code_segmentation(image, label_values):
    """
    Given a 1-channel array of class keys, colour code the segmentation results.
    # Arguments
        image: single channel array where each value represents the class key.
        label_values

    # Returns
        Colour coded image for segmentation visualization
    """
    colour_codes = np.array(label_values)
    x = colour_codes[image.astype(int)]

    return x

# classes for data loading and preprocessing
class SemanticSegmentationDataset():

    def __init__(self, root_dir, train, colormap = select_class_rgb_values, augmentation = None, preprocessing=None):
        
        self.root_dir = root_dir
        self.train = train
        self.colormap = colormap
        self.augmentation = augmentation
        self.preprocessing = preprocessing
        self.transform = torchvision.transforms.Normalize(
            mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

        self.img_dir = os.path.join(self.root_dir, "RUGD_frames-with-annotations")
        self.ann_dir = os.path.join(self.root_dir, "RUGD_annotations")
        
        # read images and allocate them to training, validation and testing sets 
        sub_train = ["creek", "park-1", "park-2", "trail-4", "trail-11","trail-12","trail-13","trail-14", "trail-5", "trail-6"]
        sub_valid = ["trail-7","trail-9", "village"]
        sub_test = ["trail-15", "trail-3", "park-8","trail","trail-10"]

        places = []
        subpath = ""
        if self.train==1:
          places = sub_train
          subpath = "training"
        elif self.train == 2:
          places = sub_test
          subpath = "testing"
        else:
          places = sub_valid
          subpath = "validation"

        image_file_names = [] 
        annotation_file_names = []
        self.img_directory = os.path.join(self.img_dir, subpath)
        self.ann_directory = os.path.join(self.ann_dir, subpath)

        for i in places:
          source_dir = os.path.join(self.img_dir, i)
          source_a_dir = os.path.join(self.ann_dir, i)

          for j in os.listdir(source_dir):
            shutil.copy(os.path.join(source_dir,j), self.img_directory) ## Or shutil.set to save memory

          for j in os.listdir(source_a_dir):
            shutil.copy(os.path.join(source_a_dir,j), self.ann_directory)
          

        ## Make sure that all frames matches with the assigned annotations
        for root, dirs, files in os.walk(self.img_directory):
          image_file_names.extend(files)
          annotation_file_names.extend(files)
          
        self.images = sorted(image_file_names)
        self.annotations = sorted(annotation_file_names)
        assert len(self.images) == len(self.annotations), "There must be as many images as there are segmentation maps"

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = cv.cvtColor(cv.imread(os.path.join(self.img_directory,self.images[idx])), cv.COLOR_BGR2RGB)
        mask = cv.cvtColor(cv.imread(os.path.join(self.ann_directory,self.annotations[idx])), cv.COLOR_BGR2RGB)
        
        # one-hot-encode the mask
        mask = one_hot_encode(mask, self.colormap).astype('float')
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask

# %% [markdown]
# # Check the dataset

# %%
# Get all information on the training, testing and validation sets
# train_set = SemanticSegmentationDataset(root_dir="/content/data", train = 1)
# test_set = SemanticSegmentationDataset(root_dir="/content/data", train = 2)
val_set = SemanticSegmentationDataset(root_dir="/content/data", train = 3)

# %%
## Length of all sets
# print("Number of training examples:", len(train_set))
print("Number of validation examples:", len(val_set))
# print("Number of testing examples:", len(test_set))
# Out:
# Number of validation examples: 465

# %%
# Check format
random_idx = np.random.randint(0, len(val_set)-1)
image, mask = val_set[random_idx]

visualize(
    original_image = image,
    ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
    one_hot_encoded_mask = reverse_one_hot(mask)
)
reverse_one_hot(mask).shape
# Out:
# (550, 688)

# %% [markdown]
# # Establish architecture

# %%
from torchvision import models

deeplab = models.segmentation.deeplabv3_resnet50(pretrained=0, progress=1, num_classes=len(CLASSES))

class SegModel(nn.Module):
    def __init__(self):
        super(SegModel,self).__init__()
        self.dl = deeplab
        
    def forward(self, x):
        y = self.dl(x)['out']
        return y
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
import segmentation_models_pytorch as smp

ENCODER = 'resnet50'
ENCODER_WEIGHTS = 'imagenet'
ACTIVATION = 'sigmoid' 

preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %% [markdown]
# # Estabish model and optimizer

# %%
# Set flag to train the model or not. If set to 'False', only prediction is performed (using an older model checkpoint)
from torch.nn import functional as F

# Set device: `cuda` or `cpu`
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = SegModel()

loss = nn.BCEWithLogitsLoss()

# define optimizer
optimizer = torch.optim.Adam([ 
    dict(params=model.parameters(), lr=0.0001),
])

# define learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(
    optimizer, gamma=0.001,
)

model.to(DEVICE)

# load best saved model checkpoint from previous commit (if present)
if os.path.exists('/content/drive/MyDrive/Colab Notebooks/best_modelDeeplabAdam3.pth'):
    model = torch.load('/content/drive/MyDrive/Colab Notebooks/best_modelDeeplabAdam3.pth', map_location=DEVICE)

# %%
## Add metrics
def meanIOU(target, predicted):
    if target.shape != predicted.shape:
        print("target has dimension", target.shape, ", predicted values have shape", predicted.shape)
        return
        
    if target.dim() != 4:
        print("target has dim", target.dim(), ", Must be 4.")
        return
    
    iousum = 0
    for i in range(target.shape[0]):
        target_arr = target[i, :, :, :].clone().detach().cpu().numpy().argmax(0)
        predicted_arr = predicted[i, :, :, :].clone().detach().cpu().numpy().argmax(0)
        
        intersection = np.logical_and(target_arr, predicted_arr).sum()
        union = np.logical_or(target_arr, predicted_arr).sum()
        if union == 0:
            iou_score = 0
        else :
            iou_score = intersection / union
        iousum +=iou_score
        
    miou = iousum/target.shape[0]
    return miou

def pixelAcc(target, predicted):    
    if target.shape != predicted.shape:
        print("target has dimension", target.shape, ", predicted values have shape", predicted.shape)
        return
        
    if target.dim() != 4:
        print("target has dim", target.dim(), ", Must be 4.")
        return
    
    accsum=0
    for i in range(target.shape[0]):
        target_arr = target[i, :, :, :].clone().detach().cpu().numpy().argmax(0)
        predicted_arr = predicted[i, :, :, :].clone().detach().cpu().numpy().argmax(0)
        
        same = (target_arr == predicted_arr).sum()
        a, b = target_arr.shape
        total = a*b
        accsum += same/total
    
    pixelAccuracy = accsum/target.shape[0]        
    return pixelAccuracy

# %%
def training_loop(n_epochs, optimizer, lr_scheduler, model, loss_fn, val_loader, train_loader = None, lastCkptPath = None):
    if torch.cuda.is_available():  
        dev = "cuda:0" 
    else:  
        dev = "cpu"
    device = torch.device(dev)
    
    tr_loss_arr = []
    val_loss_arr = []
    meanioutrain = []
    pixelacctrain = []
    meanioutest = []
    pixelacctest = []
    f1train = []
    f1test = []
    precisiontrain = []
    precisiontest = []
    recalltrain = []
    recalltest = []
    prevEpoch = 0
    
    if lastCkptPath != None :
        checkpoint = torch.load(lastCkptPath)
        prevEpoch = checkpoint['epoch']
        try:
          checkpoint.eval()
        except AttributeError as error:
          print(error)
        model = SegModel() 
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict']) 
        for state in optimizer.state.values():
          for k, v in state.items():
            if isinstance(v, torch.Tensor):
              state[k] = v.to(device).tr_loss_arr =  checkpoint['Training Loss']
        val_loss_arr =  checkpoint['Validation Loss']
        meanioutrain =  checkpoint['MeanIOU train']
        pixelacctrain =  checkpoint['PixelAcc train']
        meanioutest =  checkpoint['MeanIOU test']
        pixelacctest =  checkpoint['PixelAcc test']
        # precisiontrain = checkpoint['Precision Train']
        # precisiontest = checkpoint['Precision Test']
        # recalltrain = checkpoint['Recall Train']
        # recalltest = checkpoint['Recall Test']
        # f1train = checkpoint['F1 score Train']
        # f1test = checkpoint['F1 score Test'] 

        print("loaded model at epoch", prevEpoch)
        model.to(device)
    
    for epoch in range(0, n_epochs):
        if train_loader != None:
          train_loss = 0.0
          pixelacc = 0
          meaniou = 0
          
          pbar = tqdm(train_loader, total = len(train_loader))
          for X, y in pbar:
              torch.cuda.empty_cache()
              model.train()
              X = X.to(device).float()
              y = y.to(device).float()
              ypred = model(X)
              loss = loss_fn(ypred, y)
              
              optimizer.zero_grad()
              loss.backward()
              optimizer.step()
              
              tr_loss_arr.append(loss.item())
              meanioutrain.append(meanIOU(y, ypred))
              pixelacctrain.append(pixelAcc(y, ypred))
              # precisiontrain.append(precision(y, ypred))
              # recalltrain.append(recall(y, ypred))
              # f1train.append(f1(y, ypred))
              pbar.set_postfix({'Epoch':epoch+1+prevEpoch, 
                                'Training Loss': np.mean(tr_loss_arr),
                                'Mean IOU': np.mean(meanioutrain),
                                'Pixel Acc': np.mean(pixelacctrain),
                                # 'Precision': np.mean(precisiontrain),
                                # 'Recall':np.mean(recalltrain),
                                # 'F1 Score':np.mean(f1train)
                              })
            
        with torch.no_grad():
            
            val_loss = 0
            pbar = tqdm(val_loader, total = len(val_loader))
            for X, y in pbar:
                torch.cuda.empty_cache()
                X = X.to(device).float()
                y = y.to(device).float()
                model.eval()
                ypred = model(X)
                
                val_loss_arr.append(loss_fn(ypred, y).item())
                pixelacctest.append(pixelAcc(y, ypred))
                meanioutest.append(meanIOU(y, ypred))
                # precisiontest.append(precision(y, ypred))
                # recalltest.append(recall(y, ypred))
                # f1test.append(f1(y, ypred))
                
                pbar.set_postfix({'Epoch':epoch+1+prevEpoch, 
                                  'Validation Loss': np.mean(val_loss_arr),
                                  'Mean IOU': np.mean(meanioutest),
                                  'Pixel Acc': np.mean(pixelacctest),
                                  # 'Precision': np.mean(precisiontest),
                                  # 'Recall':np.mean(recalltest),
                                  # 'F1 Score':np.mean(f1test)
                                 })
        
        
        
        checkpoint = {
            'epoch':epoch+1+prevEpoch,
            'state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'Training Loss': tr_loss_arr,
            'Validation Loss':val_loss_arr,
            'MeanIOU train':meanioutrain, 
            'PixelAcc train':pixelacctrain, 
            'MeanIOU test':meanioutest, 
            'PixelAcc test':pixelacctest,
            # 'Precision Train': precisiontrain, 
            # 'Precision Test': precisiontest, 
            # 'Recall Train': recalltrain, 
            # 'Recall Test': recalltest, 
            # 'F1 score Train': f1train, 
            # 'F1 score Test': f1test, 
        }
        torch.save(checkpoint, '/content/best_modelDeeplabAdam.pth')
        lr_scheduler.step()
        
    return np.mean(tr_loss_arr),np.mean(val_loss_arr),np.mean(meanioutrain),np.mean(pixelacctrain), np.mean(meanioutest), np.mean(pixelacctest) #, f1train, f1test, precisiontrain, precisiontest, recalltrain ,recalltest

# %% [markdown]
# # Get epochs and augmented datasets for training and validation sets

# %%
# import albumentations
# Get train and val dataset instances
train_dataset = SemanticSegmentationDataset(
    root_dir='/content/data', 
    train = 1,
    augmentation = get_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn)
)

valid_dataset = SemanticSegmentationDataset(
    root_dir = '/content/data', 
    train=3,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn)
)

# %% [markdown]
# # Dataloaders

# %%
# Get train and val data loaders
train_loader = DataLoader(train_dataset, batch_size=20, shuffle=True, num_workers=0, pin_memory=True)
valid_loader = DataLoader(valid_dataset, batch_size=20, shuffle=False, num_workers=0, pin_memory=True)

# %% [markdown]
# # **Train the model**
# When tested in range 1-25, the optimal so far is 3 epochs, but feel free to adjust the number at EPOCHS in line 12

# %%
# %%time
retval = training_loop(5, 
                       optimizer, 
                       lr_scheduler, 
                       model, 
                       loss, 
                       train_loader, 
                       valid_loader)
# Out:
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/249 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
# CPU times: user 3h 23min 35s, sys: 22min 7s, total: 3h 45min 42s
# Wall time: 3h 44min 53s

# %%
# load best saved model checkpoint from the current run
ckp = ""
if os.path.exists('/content/best_modelDeeplabAdam.pth'):
    model = torch.load('/content/best_modelDeeplabAdam.pth', map_location=DEVICE)
    ckp = '/content/best_modelFCNAdam.pth'
    print('Loaded FCN + Adam model from this run.')

# load best saved model checkpoint from previous commit (if present)
elif os.path.exists('/content/drive/MyDrive/Colab Notebooks/best_modelDeeplabAdam3.pth'):
    model = torch.load('/content/drive/MyDrive/Colab Notebooks/best_modelDeeplabAdam3.pth', map_location=DEVICE)
    ckp = '/content/drive/MyDrive/Colab Notebooks/best_modelDeeplabAdam3.pth'
    print('Loaded FCN+Adam model from a previous commit.')
# Out:
# Loaded FCN+Adam model from a previous commit.

# %% [markdown]
# # Run model on **testing set**

# %%
# create test dataloader (with preprocessing operation: to_tensor(...))
test_dataset = SemanticSegmentationDataset(
    root_dir = "/content/data", 
    train = 2,
)

# test dataset for visualization (without preprocessing augmentations & transformations)
# get a random test image/mask index
random_idx = np.random.randint(0, len(test_dataset)-1)
image, mask = test_dataset[random_idx]
visualize(
    original_image = image,
    ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
    one_hot_encoded_mask = reverse_one_hot(mask)
)

# %%
preds_folder = '/content/predictionsDeeplabAdam/'
if not os.path.exists(preds_folder):
    os.makedirs("/content/predictionsDeeplabAdam/")

# %%
test_dataset = SemanticSegmentationDataset(
    root_dir='/content/data', 
    train = 2,
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn)
)

test_dataloader = DataLoader(test_dataset, batch_size=20, shuffle=True, num_workers=0, pin_memory=True)

# %% [markdown]
# # **Inference, Metrics Evaluation and Visualisation**

# %%
# Testing
testmodel = SegModel() 
testmodel.to(DEVICE)
retval = training_loop(1, 
                       optimizer, 
                       lr_scheduler, 
                       model, 
                       loss, 
                       test_dataloader,
                       lastCkptPath=ckp)

testmodel.load_state_dict(model['state_dict'])
testmodel.to(DEVICE).float()
# Out:
# 'dict' object has no attribute 'eval'
# loaded model at epoch 3
#   0%|          | 0/101 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SegModel(
#   (dl): DeepLabV3(
#     (backbone): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (classifier): DeepLabHead(
#       (0): ASPP(
#         (convs): ModuleList(
#           (0): Sequential(
#             (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (1): ASPPConv(
#             (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (2): ASPPConv(
#             (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (3): ASPPConv(
#             (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU()
#           )
#           (4): ASPPPooling(
#             (0): AdaptiveAvgPool2d(output_size=1)
#             (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): ReLU()
#           )
#         )
#         (project): Sequential(
#           (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Dropout(p=0.5, inplace=False)
#         )
#       )
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#       (4): Conv2d(256, 24, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
tr_loss_arr, val_loss_arr, meanioutrain, pixelacctrain, meanioutest, pixelacctest = retval
print("Evaluation on Test Data: ")
print(f"Mean Accuracy: {pixelacctest:.4f}")
print(f"Mean Loss: {val_loss_arr:.4f}")
print(f"Mean IoU Score: {meanioutest:.4f}")
# Out:
# Evaluation on Test Data:
# Mean Accuracy: 0.6459
# Mean Loss: 0.0658
# Mean IoU Score: 0.8608

# %%
## For sample illustrations
# Center crop padded image / mask to original image dims
def crop_image(image, true_dimensions):
    return album.CenterCrop(p=1,height=304, width=304)(image=image)

# test dataset for visualization
test_dataset_vis = SemanticSegmentationDataset(
    root_dir='/content/data',
    train = 2,
    augmentation=get_validation_augmentation(),
)

# %%
from random import randint

for idx in range(500):
    image, gt_mask = test_dataset[idx]
    image_vis = test_dataset_vis[idx][0].astype('uint8')
    true_dimensions = image_vis.shape
    x_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
    # Predict test image
    pred_mask = testmodel(x_tensor)
    pred_mask = pred_mask.detach().squeeze().cpu().numpy()
    # Convert pred_mask from `CHW` format to `HWC` format
    pred_mask = np.transpose(pred_mask,(1,2,0))
    pred_mask = cv.resize(pred_mask,(304,304))

    # Get prediction channel corresponding to sky, or any classes available
    pred_foreground_heatmap = crop_image(pred_mask[:,:,CLASSES.index("sky")], true_dimensions)['image']
    pred_mask = crop_image(colour_code_segmentation(reverse_one_hot(pred_mask), select_class_rgb_values), true_dimensions)['image']
    # Convert gt_mask from `CHW` format to `HWC` format
    gt_mask = np.transpose(gt_mask,(1,2,0))
    gt_mask = crop_image(colour_code_segmentation(reverse_one_hot(gt_mask), select_class_rgb_values), true_dimensions)['image']
    cv.imwrite(os.path.join(preds_folder, f"pred_{idx}.png"), np.hstack([pred_mask])[::])
    
    visualize(
        original_image = image_vis,
        ground_truth_mask = gt_mask,
        predicted_mask = pred_mask,
        pred_foreground_heatmap = pred_foreground_heatmap
    )

# %%
## Copy all info:
with open('inferenceDeeplabAdam.txt', 'w') as convert_file:
  convert_file.write("\Test loss")
  convert_file.write(str(val_loss_arr))
  convert_file.write("\nMean IOU test")
  convert_file.write(str(meanioutest))
  convert_file.write("\nPixel accuracy test")
  convert_file.write(str(pixelacctest))

# %%
## Download predictions and trained model
# !zip -r /content/predictionsDeeplabAdam.zip /content/predictionsDeeplabAdam
from google.colab import files
files.download("/content/predictionsDeeplabAdam.zip")
files.download("/content/best_modelDeeplabAdam.pth")
files.download("/content/data/inferenceDeeplabAdam.txt")
# Out:
# updating: content/predictionsDeeplabAdam/ (stored 0%)
# updating: content/predictionsDeeplabAdam/pred_19.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_447.png (deflated 25%)
# updating: content/predictionsDeeplabAdam/pred_348.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_197.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_155.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_46.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_398.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_206.png (deflated 23%)
# updating: content/predictionsDeeplabAdam/pred_156.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_458.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_449.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_43.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_408.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_309.png (deflated 45%)
# updating: content/predictionsDeeplabAdam/pred_387.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_296.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_198.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_40.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_372.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_33.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_320.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_58.png (deflated 49%)
# updating: content/predictionsDeeplabAdam/pred_8.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_441.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_159.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_95.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_329.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_361.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_103.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_473.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_287.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_88.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_100.png (deflated 22%)
# updating: content/predictionsDeeplabAdam/pred_86.png (deflated 46%)
# updating: content/predictionsDeeplabAdam/pred_290.png (deflated 48%)
# updating: content/predictionsDeeplabAdam/pred_477.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_170.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_18.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_316.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_483.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_299.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_471.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_173.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_98.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_418.png (deflated 9%)
# updating: content/predictionsDeeplabAdam/pred_399.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_456.png (deflated 22%)
# updating: content/predictionsDeeplabAdam/pred_237.png (deflated 22%)
# updating: content/predictionsDeeplabAdam/pred_393.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_54.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_404.png (deflated 21%)
# updating: content/predictionsDeeplabAdam/pred_451.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_62.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_82.png (deflated 55%)
# updating: content/predictionsDeeplabAdam/pred_317.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_78.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_1.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_461.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_370.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_397.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_342.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_341.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_181.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_444.png (deflated 23%)
# updating: content/predictionsDeeplabAdam/pred_164.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_416.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_195.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_360.png (deflated 17%)
# updating: content/predictionsDeeplabAdam/pred_140.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_117.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_494.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_115.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_478.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_42.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_476.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_111.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_187.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_153.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_369.png (deflated 40%)
# updating: content/predictionsDeeplabAdam/pred_440.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_22.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_273.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_26.png (deflated 40%)
# updating: content/predictionsDeeplabAdam/pred_460.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_127.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_422.png (deflated 9%)
# updating: content/predictionsDeeplabAdam/pred_109.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_366.png (deflated 21%)
# updating: content/predictionsDeeplabAdam/pred_430.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_484.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_139.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_228.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_64.png (deflated 57%)
# updating: content/predictionsDeeplabAdam/pred_214.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_235.png (deflated 17%)
# updating: content/predictionsDeeplabAdam/pred_247.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_94.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_454.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_424.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_179.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_230.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_489.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_356.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_425.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_138.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_245.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_16.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_76.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_190.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_194.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_192.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_129.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_276.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_307.png (deflated 50%)
# updating: content/predictionsDeeplabAdam/pred_162.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_204.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_101.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_388.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_69.png (deflated 41%)
# updating: content/predictionsDeeplabAdam/pred_411.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_180.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_357.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_283.png (deflated 40%)
# updating: content/predictionsDeeplabAdam/pred_269.png (deflated 48%)
# updating: content/predictionsDeeplabAdam/pred_41.png (deflated 41%)
# updating: content/predictionsDeeplabAdam/pred_475.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_29.png (deflated 46%)
# updating: content/predictionsDeeplabAdam/pred_174.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_248.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_358.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_70.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_74.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_381.png (deflated 41%)
# updating: content/predictionsDeeplabAdam/pred_223.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_66.png (deflated 51%)
# updating: content/predictionsDeeplabAdam/pred_410.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_131.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_203.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_30.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_351.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_15.png (deflated 41%)
# updating: content/predictionsDeeplabAdam/pred_354.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_212.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_262.png (deflated 59%)
# updating: content/predictionsDeeplabAdam/pred_325.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_435.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_121.png (deflated 47%)
# updating: content/predictionsDeeplabAdam/pred_450.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_374.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_150.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_270.png (deflated 51%)
# updating: content/predictionsDeeplabAdam/pred_306.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_207.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_160.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_297.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_79.png (deflated 51%)
# updating: content/predictionsDeeplabAdam/pred_280.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_72.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_349.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_141.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_293.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_336.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_17.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_278.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_464.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_386.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_350.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_157.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_472.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_123.png (deflated 53%)
# updating: content/predictionsDeeplabAdam/pred_25.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_217.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_215.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_267.png (deflated 51%)
# updating: content/predictionsDeeplabAdam/pred_254.png (deflated 62%)
# updating: content/predictionsDeeplabAdam/pred_142.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_264.png (deflated 57%)
# updating: content/predictionsDeeplabAdam/pred_130.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_339.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_171.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_282.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_128.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_37.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_49.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_12.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_428.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_436.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_20.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_136.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_36.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_288.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_379.png (deflated 41%)
# updating: content/predictionsDeeplabAdam/pred_268.png (deflated 49%)
# updating: content/predictionsDeeplabAdam/pred_328.png (deflated 25%)
# updating: content/predictionsDeeplabAdam/pred_431.png (deflated 17%)
# updating: content/predictionsDeeplabAdam/pred_240.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_427.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_390.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_446.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_50.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_183.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_426.png (deflated 10%)
# updating: content/predictionsDeeplabAdam/pred_364.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_211.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_319.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_133.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_497.png (deflated 23%)
# updating: content/predictionsDeeplabAdam/pred_405.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_14.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_481.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_87.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_263.png (deflated 61%)
# updating: content/predictionsDeeplabAdam/pred_345.png (deflated 17%)
# updating: content/predictionsDeeplabAdam/pred_302.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_252.png (deflated 46%)
# updating: content/predictionsDeeplabAdam/pred_493.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_443.png (deflated 22%)
# updating: content/predictionsDeeplabAdam/pred_415.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_353.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_496.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_209.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_21.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_421.png (deflated 10%)
# updating: content/predictionsDeeplabAdam/pred_99.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_221.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_371.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_178.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_495.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_279.png (deflated 41%)
# updating: content/predictionsDeeplabAdam/pred_334.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_429.png (deflated 22%)
# updating: content/predictionsDeeplabAdam/pred_144.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_39.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_437.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_6.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_318.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_482.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_9.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_340.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_373.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_301.png (deflated 46%)
# updating: content/predictionsDeeplabAdam/pred_185.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_119.png (deflated 53%)
# updating: content/predictionsDeeplabAdam/pred_378.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_363.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_126.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_346.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_65.png (deflated 60%)
# updating: content/predictionsDeeplabAdam/pred_321.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_210.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_148.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_455.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_300.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_395.png (deflated 52%)
# updating: content/predictionsDeeplabAdam/pred_362.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_292.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_291.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_92.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_232.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_23.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_124.png (deflated 53%)
# updating: content/predictionsDeeplabAdam/pred_324.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_137.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_498.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_93.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_219.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_158.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_154.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_226.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_147.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_323.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_400.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_326.png (deflated 23%)
# updating: content/predictionsDeeplabAdam/pred_199.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_191.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_201.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_376.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_122.png (deflated 48%)
# updating: content/predictionsDeeplabAdam/pred_151.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_106.png (deflated 25%)
# updating: content/predictionsDeeplabAdam/pred_412.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_275.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_83.png (deflated 50%)
# updating: content/predictionsDeeplabAdam/pred_343.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_238.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_236.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_102.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_31.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_59.png (deflated 60%)
# updating: content/predictionsDeeplabAdam/pred_286.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_61.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_294.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_391.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_167.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_48.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_467.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_56.png (deflated 49%)
# updating: content/predictionsDeeplabAdam/pred_355.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_375.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_3.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_134.png (deflated 47%)
# updating: content/predictionsDeeplabAdam/pred_271.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_382.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_439.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_53.png (deflated 56%)
# updating: content/predictionsDeeplabAdam/pred_120.png (deflated 59%)
# updating: content/predictionsDeeplabAdam/pred_420.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_75.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_91.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_265.png (deflated 70%)
# updating: content/predictionsDeeplabAdam/pred_303.png (deflated 45%)
# updating: content/predictionsDeeplabAdam/pred_107.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_32.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_452.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_186.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_419.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_312.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_168.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_466.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_246.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_0.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_220.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_256.png (deflated 52%)
# updating: content/predictionsDeeplabAdam/pred_311.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_433.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_85.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_161.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_233.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_89.png (deflated 40%)
# updating: content/predictionsDeeplabAdam/pred_487.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_218.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_244.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_261.png (deflated 64%)
# updating: content/predictionsDeeplabAdam/pred_486.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_184.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_90.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_84.png (deflated 48%)
# updating: content/predictionsDeeplabAdam/pred_196.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_205.png (deflated 25%)
# updating: content/predictionsDeeplabAdam/pred_97.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_485.png (deflated 10%)
# updating: content/predictionsDeeplabAdam/pred_383.png (deflated 41%)
# updating: content/predictionsDeeplabAdam/pred_249.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_492.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_145.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_193.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_146.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_71.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_125.png (deflated 46%)
# updating: content/predictionsDeeplabAdam/pred_81.png (deflated 62%)
# updating: content/predictionsDeeplabAdam/pred_108.png (deflated 21%)
# updating: content/predictionsDeeplabAdam/pred_459.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_304.png (deflated 45%)
# updating: content/predictionsDeeplabAdam/pred_96.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_347.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_480.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_45.png (deflated 47%)
# updating: content/predictionsDeeplabAdam/pred_308.png (deflated 49%)
# updating: content/predictionsDeeplabAdam/pred_344.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_305.png (deflated 40%)
# updating: content/predictionsDeeplabAdam/pred_396.png (deflated 46%)
# updating: content/predictionsDeeplabAdam/pred_434.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_335.png (deflated 17%)
# updating: content/predictionsDeeplabAdam/pred_225.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_448.png (deflated 21%)
# updating: content/predictionsDeeplabAdam/pred_52.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_2.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_73.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_315.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_176.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_4.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_258.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_202.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_417.png (deflated 10%)
# updating: content/predictionsDeeplabAdam/pred_116.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_38.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_234.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_189.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_241.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_255.png (deflated 58%)
# updating: content/predictionsDeeplabAdam/pred_172.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_200.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_77.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_55.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_359.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_114.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_313.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_277.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_310.png (deflated 47%)
# updating: content/predictionsDeeplabAdam/pred_384.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_289.png (deflated 52%)
# updating: content/predictionsDeeplabAdam/pred_414.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_389.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_213.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_462.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_445.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_63.png (deflated 45%)
# updating: content/predictionsDeeplabAdam/pred_314.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_338.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_285.png (deflated 40%)
# updating: content/predictionsDeeplabAdam/pred_406.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_250.png (deflated 46%)
# updating: content/predictionsDeeplabAdam/pred_385.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_465.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_80.png (deflated 51%)
# updating: content/predictionsDeeplabAdam/pred_208.png (deflated 22%)
# updating: content/predictionsDeeplabAdam/pred_469.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_274.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_453.png (deflated 21%)
# updating: content/predictionsDeeplabAdam/pred_34.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_377.png (deflated 34%)
# updating: content/predictionsDeeplabAdam/pred_479.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_392.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_188.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_24.png (deflated 45%)
# updating: content/predictionsDeeplabAdam/pred_13.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_333.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_229.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_266.png (deflated 59%)
# updating: content/predictionsDeeplabAdam/pred_490.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_112.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_47.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_337.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_468.png (deflated 16%)
# updating: content/predictionsDeeplabAdam/pred_284.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_231.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_438.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_330.png (deflated 19%)
# updating: content/predictionsDeeplabAdam/pred_166.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_163.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_44.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_35.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_182.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_463.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_239.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_380.png (deflated 40%)
# updating: content/predictionsDeeplabAdam/pred_322.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_432.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_402.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_474.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_491.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_365.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_488.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_175.png (deflated 37%)
# updating: content/predictionsDeeplabAdam/pred_327.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_403.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_401.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_143.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_260.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_10.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_295.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_352.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_67.png (deflated 46%)
# updating: content/predictionsDeeplabAdam/pred_394.png (deflated 53%)
# updating: content/predictionsDeeplabAdam/pred_227.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_60.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_113.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_423.png (deflated 13%)
# updating: content/predictionsDeeplabAdam/pred_177.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_132.png (deflated 32%)
# updating: content/predictionsDeeplabAdam/pred_332.png (deflated 11%)
# updating: content/predictionsDeeplabAdam/pred_470.png (deflated 22%)
# updating: content/predictionsDeeplabAdam/pred_118.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_5.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_251.png (deflated 42%)
# updating: content/predictionsDeeplabAdam/pred_110.png (deflated 26%)
# updating: content/predictionsDeeplabAdam/pred_149.png (deflated 31%)
# updating: content/predictionsDeeplabAdam/pred_257.png (deflated 45%)
# updating: content/predictionsDeeplabAdam/pred_253.png (deflated 62%)
# updating: content/predictionsDeeplabAdam/pred_57.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_243.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_216.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_104.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_413.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_68.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_442.png (deflated 18%)
# updating: content/predictionsDeeplabAdam/pred_169.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_222.png (deflated 23%)
# updating: content/predictionsDeeplabAdam/pred_368.png (deflated 33%)
# updating: content/predictionsDeeplabAdam/pred_135.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_407.png (deflated 12%)
# updating: content/predictionsDeeplabAdam/pred_367.png (deflated 30%)
# updating: content/predictionsDeeplabAdam/pred_28.png (deflated 44%)
# updating: content/predictionsDeeplabAdam/pred_51.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_11.png (deflated 27%)
# updating: content/predictionsDeeplabAdam/pred_259.png (deflated 41%)
# updating: content/predictionsDeeplabAdam/pred_7.png (deflated 35%)
# updating: content/predictionsDeeplabAdam/pred_331.png (deflated 15%)
# updating: content/predictionsDeeplabAdam/pred_224.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_242.png (deflated 29%)
# updating: content/predictionsDeeplabAdam/pred_298.png (deflated 36%)
# updating: content/predictionsDeeplabAdam/pred_105.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_499.png (deflated 20%)
# updating: content/predictionsDeeplabAdam/pred_281.png (deflated 38%)
# updating: content/predictionsDeeplabAdam/pred_165.png (deflated 24%)
# updating: content/predictionsDeeplabAdam/pred_152.png (deflated 39%)
# updating: content/predictionsDeeplabAdam/pred_457.png (deflated 14%)
# updating: content/predictionsDeeplabAdam/pred_272.png (deflated 28%)
# updating: content/predictionsDeeplabAdam/pred_27.png (deflated 43%)
# updating: content/predictionsDeeplabAdam/pred_409.png (deflated 17%)
